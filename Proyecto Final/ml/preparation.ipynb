# %% [markdown]
# # Preparing data

# %% [markdown]
# Getting some stats for each restaurant to find a metric to classify between a good and a bad business.

# %%
import pandas as pd

# %%
restaurants_df = pd.read_csv('restaurants.csv')
waiters_df = pd.read_csv('waiters.csv')
transactions_df = pd.read_csv('transactions.csv')

# %%
restaurants_df.head()
# Out:
#    ID             Name      Food Type  \
# 0   1    Ocean's Catch  Mediterranean
# 1   2   Spice Symphony       American
# 2   3  La Bella Cucina        Chinese
# 3   4   The Burger Bar        Mexican
# 4   5    Veggie Garden           Cafe
#
#                                              Details Smoking Area Price Range  \
# 0  Fresh seafood dishes with a coastal vibe, insp...          Yes         $$$
# 1  An orchestra of flavors from around the world ...          Yes         $$$
# 2  Authentic Italian cuisine served in a cozy, fa...           No        $$$$
# 3  Classic and gourmet burgers with a variety of ...           No           $
# 4  A plant-based paradise featuring vibrant, fres...          Yes         $$$
#
#           City State                       Image
# 0      Houston    TX   pexels-photo-2042591.jpeg
# 1    San Diego    TX  pexels-photo-29172133.jpeg
# 2  Los Angeles    TX  pexels-photo-29132866.jpeg
# 3       Dallas    AZ   pexels-photo-7317354.jpeg
# 4  Los Angeles    TX  pexels-photo-28577205.jpeg

# %%
waiters_df.head()
# Out:
#    ID          Name  Restaurant
# 0   1   Sawyer Gray           1
# 1   2  Shawn Morris           1
# 2   3  Robin Brooks           1
# 3   4  Bailey Adams           2
# 4   5    Blake Ross           2

# %%
transactions_df.head()
# Out:
#    ID  Waiter  People   Total    Tip            Timestamp  Payment Method
# 0   1       1      10  155.51  16.97  2024-09-09 09:34:00      Debit Card
# 1   2       1       3  111.61   8.27  2024-09-05 05:05:00      Debit Card
# 2   3       1       9  191.98  36.99  2024-10-27 02:34:00            Cash
# 3   4       1       5  123.16  15.39  2024-08-20 19:30:00  Mobile Payment
# 4   5       1       6   24.14   3.77  2024-08-19 16:09:00            Cash

# %%
restaurants_df = restaurants_df.merge(waiters_df["Restaurant"].value_counts().reset_index().rename(columns={"count": "Waiter Count"}), left_on="ID", right_on="Restaurant")
restaurants_df.head()
# Out:
#    ID             Name      Food Type  \
# 0   1    Ocean's Catch  Mediterranean
# 1   2   Spice Symphony       American
# 2   3  La Bella Cucina        Chinese
# 3   4   The Burger Bar        Mexican
# 4   5    Veggie Garden           Cafe
#
#                                              Details Smoking Area Price Range  \
# 0  Fresh seafood dishes with a coastal vibe, insp...          Yes         $$$
# 1  An orchestra of flavors from around the world ...          Yes         $$$
# 2  Authentic Italian cuisine served in a cozy, fa...           No        $$$$
# 3  Classic and gourmet burgers with a variety of ...           No           $
# 4  A plant-based paradise featuring vibrant, fres...          Yes         $$$
#
#           City State                       Image  Restaurant  Waiter Count
# 0      Houston    TX   pexels-photo-2042591.jpeg           1             3
# 1    San Diego    TX  pexels-photo-29172133.jpeg           2             6
# 2  Los Angeles    TX  pexels-photo-29132866.jpeg           3            10
# 3       Dallas    AZ   pexels-photo-7317354.jpeg           4             4
# 4  Los Angeles    TX  pexels-photo-28577205.jpeg           5             3

# %%
transactions_df["Timestamp"] = pd.to_datetime(transactions_df["Timestamp"])
transactions_df.head()
# Out:
#    ID  Waiter  People   Total    Tip           Timestamp  Payment Method
# 0   1       1      10  155.51  16.97 2024-09-09 09:34:00      Debit Card
# 1   2       1       3  111.61   8.27 2024-09-05 05:05:00      Debit Card
# 2   3       1       9  191.98  36.99 2024-10-27 02:34:00            Cash
# 3   4       1       5  123.16  15.39 2024-08-20 19:30:00  Mobile Payment
# 4   5       1       6   24.14   3.77 2024-08-19 16:09:00            Cash

# %%
transactions_df = transactions_df.merge(waiters_df.rename(columns={"ID": "Waiter"})[["Waiter", "Restaurant"]], left_on="Waiter", right_on="Waiter")
transactions_df.head()
# Out:
#    ID  Waiter  People   Total    Tip           Timestamp  Payment Method  \
# 0   1       1      10  155.51  16.97 2024-09-09 09:34:00      Debit Card
# 1   2       1       3  111.61   8.27 2024-09-05 05:05:00      Debit Card
# 2   3       1       9  191.98  36.99 2024-10-27 02:34:00            Cash
# 3   4       1       5  123.16  15.39 2024-08-20 19:30:00  Mobile Payment
# 4   5       1       6   24.14   3.77 2024-08-19 16:09:00            Cash
#
#    Restaurant
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
transactions_df["Month"] = transactions_df["Timestamp"].dt.to_period("M").dt.start_time
transactions_df.head()
# Out:
#    ID  Waiter  People   Total    Tip           Timestamp  Payment Method  \
# 0   1       1      10  155.51  16.97 2024-09-09 09:34:00      Debit Card
# 1   2       1       3  111.61   8.27 2024-09-05 05:05:00      Debit Card
# 2   3       1       9  191.98  36.99 2024-10-27 02:34:00            Cash
# 3   4       1       5  123.16  15.39 2024-08-20 19:30:00  Mobile Payment
# 4   5       1       6   24.14   3.77 2024-08-19 16:09:00            Cash
#
#    Restaurant      Month
# 0           1 2024-09-01
# 1           1 2024-09-01
# 2           1 2024-10-01
# 3           1 2024-08-01
# 4           1 2024-08-01

# %%
monthly_means = transactions_df.groupby(["Month", "Restaurant"])[["People", "Total", "Tip"]].mean().reset_index().groupby("Restaurant")[["People", "Total", "Tip"]].mean().reset_index()
monthly_means.head()
# Out:
#    Restaurant    People       Total        Tip
# 0           1  6.119587  110.367585  13.808969
# 1           2  5.727653  109.592477  14.036327
# 2           3  5.311244  111.868814  13.980220
# 3           4  5.325480  108.776504  13.046276
# 4           5  5.645668  109.974089  13.949825

# %%
payment_method_mode = transactions_df.groupby('Restaurant')['Payment Method'].agg(lambda x: x.mode().iloc[0]).reset_index()
payment_method_mode.head()
# Out:
#    Restaurant Payment Method
# 0           1     Debit Card
# 1           2           Cash
# 2           3           Cash
# 3           4           Cash
# 4           5    Credit Card

# %%
restaurants_df = restaurants_df.merge(monthly_means, left_on="ID", right_on="Restaurant").merge(payment_method_mode, left_on="ID", right_on="Restaurant")
restaurants_df.head()
# Out:
#    ID             Name      Food Type  \
# 0   1    Ocean's Catch  Mediterranean
# 1   2   Spice Symphony       American
# 2   3  La Bella Cucina        Chinese
# 3   4   The Burger Bar        Mexican
# 4   5    Veggie Garden           Cafe
#
#                                              Details Smoking Area Price Range  \
# 0  Fresh seafood dishes with a coastal vibe, insp...          Yes         $$$
# 1  An orchestra of flavors from around the world ...          Yes         $$$
# 2  Authentic Italian cuisine served in a cozy, fa...           No        $$$$
# 3  Classic and gourmet burgers with a variety of ...           No           $
# 4  A plant-based paradise featuring vibrant, fres...          Yes         $$$
#
#           City State                       Image  Restaurant_x  Waiter Count  \
# 0      Houston    TX   pexels-photo-2042591.jpeg             1             3
# 1    San Diego    TX  pexels-photo-29172133.jpeg             2             6
# 2  Los Angeles    TX  pexels-photo-29132866.jpeg             3            10
# 3       Dallas    AZ   pexels-photo-7317354.jpeg             4             4
# 4  Los Angeles    TX  pexels-photo-28577205.jpeg             5             3
#
#    Restaurant_y    People       Total        Tip  Restaurant Payment Method
# 0             1  6.119587  110.367585  13.808969           1     Debit Card
# 1             2  5.727653  109.592477  14.036327           2           Cash
# 2             3  5.311244  111.868814  13.980220           3           Cash
# 3             4  5.325480  108.776504  13.046276           4           Cash
# 4             5  5.645668  109.974089  13.949825           5    Credit Card

# %%
restaurants_df = restaurants_df.drop(columns=["Restaurant", "Restaurant_x", "Restaurant_y"])

# %%
import numpy as np

# Adding a column for the classifcation of the restaurants based on the average tip amount per month (good or bad)
def classify_tip(tip, monthly_average):
    if tip > monthly_average:
        return "Good" if np.random.uniform() < 0.9 else "Bad"
    return "Bad" if np.random.uniform() < 0.9 else "Good"

# %%
restaurants_df["Classification"] = restaurants_df.apply(lambda row: classify_tip(row["Tip"], restaurants_df["Tip"].mean()), axis=1)
restaurants_df.head()
# Out:
#    ID             Name      Food Type  \
# 0   1    Ocean's Catch  Mediterranean
# 1   2   Spice Symphony       American
# 2   3  La Bella Cucina        Chinese
# 3   4   The Burger Bar        Mexican
# 4   5    Veggie Garden           Cafe
#
#                                              Details Smoking Area Price Range  \
# 0  Fresh seafood dishes with a coastal vibe, insp...          Yes         $$$
# 1  An orchestra of flavors from around the world ...          Yes         $$$
# 2  Authentic Italian cuisine served in a cozy, fa...           No        $$$$
# 3  Classic and gourmet burgers with a variety of ...           No           $
# 4  A plant-based paradise featuring vibrant, fres...          Yes         $$$
#
#           City State                       Image  Waiter Count    People  \
# 0      Houston    TX   pexels-photo-2042591.jpeg             3  6.119587
# 1    San Diego    TX  pexels-photo-29172133.jpeg             6  5.727653
# 2  Los Angeles    TX  pexels-photo-29132866.jpeg            10  5.311244
# 3       Dallas    AZ   pexels-photo-7317354.jpeg             4  5.325480
# 4  Los Angeles    TX  pexels-photo-28577205.jpeg             3  5.645668
#
#         Total        Tip Payment Method Classification
# 0  110.367585  13.808969     Debit Card           Good
# 1  109.592477  14.036327           Cash           Good
# 2  111.868814  13.980220           Cash           Good
# 3  108.776504  13.046276           Cash            Bad
# 4  109.974089  13.949825    Credit Card           Good

# %%
restaurants_df.to_csv('restaurants_with_metrics.csv', index=False)
